# %%
import pandas as pd
import json

# %%
with open('./Desktop/whole_quran copy.json') as f:
    data = json.load(f)

# %%
# flat_data = pd.json_normalize(data)
df = pd.DataFrame(data); df
# Out:
#                                                        fatihah  \
# text         {'1': 'Биринчи бөлүм  ', '2': 'Меккеде түшкөн....
# explanation  {'1': 'Фатиха - бетачар.', '2': 'Ар бир сүрөнү...
#
#                                                        baqarah  \
# text         {'1': ' ', '2': 'Мээримдүү, Ырайымдуу Алланын ...
# explanation  {'1': 'Бакара-Уй', '2': 'Бул аяттын мааниси жа...
#
#                                                     al_e_imran  \
# text         {'1': ' Меккеде түшкөн. Эки жүз айаттан турат....
# explanation  {'1': 'Имрандын үй бүлөсү', '2': 'Бакара сүрөс...
#
#                                                           nisa  \
# text         {'1': ' ', '2': 'Мединада тшүрүлгөн. Жүз жетим...
# explanation  {'1': 'Айалдар', '2': 'Адам атадан.', '3': 'Ту...
#
#                                                         maidah  \
# text         {'1': 'Мединада түшкөн. Жүз жыйырма айаттан ту...
# explanation  {'1': 'Дасторкон', '2': 'Ажылык парзын аткарып...
#
# ...

# %%
df = df.T

# %%
df
# Out:
#                                                          text  \
# fatihah     {'1': 'Биринчи бөлүм  ', '2': 'Меккеде түшкөн....
# baqarah     {'1': ' ', '2': 'Мээримдүү, Ырайымдуу Алланын ...
# al_e_imran  {'1': ' Меккеде түшкөн. Эки жүз айаттан турат....
# nisa        {'1': ' ', '2': 'Мединада тшүрүлгөн. Жүз жетим...
# maidah      {'1': 'Мединада түшкөн. Жүз жыйырма айаттан ту...
# ...                                                       ...
# nasr        {'1': 'Мединада түшүрүлгөн. үч айаттан турат. ...
# masad       {'1': 'Меккеде түшүрүлгөн. Беш айаттан турат. ...
# ikhlas      {'1': 'Меккеде түшүрүлгөн. Төрт айаттан турат....
# falaq       {'1': 'Меккеде түшүрүлгөн. Беш айаттан турат. ...
# nas         {'1': 'Меккеде түшүрүлгөн . Алты айаттан турат...
#
#                                                   explanation
# fatihah     {'1': 'Фатиха - бетачар.', '2': 'Ар бир сүрөнү...
# baqarah     {'1': 'Бакара-Уй', '2': 'Бул аяттын мааниси жа...
# ...

# %%
df.head()
# Out:
#                                                          text  \
# fatihah     {'1': 'Биринчи бөлүм  ', '2': 'Меккеде түшкөн....
# baqarah     {'1': ' ', '2': 'Мээримдүү, Ырайымдуу Алланын ...
# al_e_imran  {'1': ' Меккеде түшкөн. Эки жүз айаттан турат....
# nisa        {'1': ' ', '2': 'Мединада тшүрүлгөн. Жүз жетим...
# maidah      {'1': 'Мединада түшкөн. Жүз жыйырма айаттан ту...
#
#                                                   explanation
# fatihah     {'1': 'Фатиха - бетачар.', '2': 'Ар бир сүрөнү...
# baqarah     {'1': 'Бакара-Уй', '2': 'Бул аяттын мааниси жа...
# al_e_imran  {'1': 'Имрандын үй бүлөсү', '2': 'Бакара сүрөс...
# nisa        {'1': 'Айалдар', '2': 'Адам атадан.', '3': 'Ту...
# maidah      {'1': 'Дасторкон', '2': 'Ажылык парзын аткарып...

# %%
df.loc['saba']['explanation']
# Out:
# {'1': 'Саба – бүгүнкү күндөгү Йемендин борбор шаарына тиешелүү анын байыркы аталышы.',
#  '2': 'Периштелерди, аяттарды, кабарларды.',
#  '3': 'Биротоло чирип…',
#  '4': 'Темирден согулгган аскер кийими.',
#  '5': 'Сулайман (а.с.)ды.',
#  '6': 'Курт.',
#  '7': 'Сулайман (а.с.) өлгөндө Алланын амири менен таягына сүйөнгөн абалда тура берген. Алланын амири менен жер алдынан шамир аттуу курт чыгып, таягын жеп, кесип салган. Ошондо Сулайман кулап түшкөн.',
#  '8': 'Жиндер.',
#  '9': 'Дауддун тукумдары ал жумуштарды кубануу менен аткарып, Аллага шүгүрчүлүк кылып жатышса, а жиндер өздөрү аткарып жаткан жумушту жаза катары түшүнүшкөн.',
#  '10': 'Эгер Сулайман өлгөнүн билген болсо, жумуштарды мүмкүн ошол замат токтотмок.',
#  '11': 'Саба - Араб урууларынын биринин аты. Чоң аталарынын атынан аталып калган. Ошондой эле, Йемен падышалыгынын титулу болгон. Сулайман (а.с.)дын доорунда, Билкыс падыша да ушулардан.',
# ...

# %%
for name, row in df.iterrows():
    for texp, content in row.items():
        # print(content)
        for key, sent in content.items():
            content[key] = sent.replace('\xa0', '').replace('ъ', 'ө').replace('Ъ', 'Ө').replace('\\', 'ү').replace('ё','ң').replace('/', 'Ү').replace('йа', 'я').replace('йу','ю').replace('йо','ё').replace('Марям','Марьям').replace('Йахя','Йахья').replace('Банямин','Баньямин').replace('Аюп','Айюп').replace('Аюб','Айюп').replace('Иляс', 'Ильяс').replace('Машар-ьул-Харамда','Машьар-ул-Харамда').replace('`', '').replace('–', '-').replace('–', '-').replace('ьүберишкен', 'беришкен').replace('  ', ' ').replace('  ', ' ').strip() #.replace('Йу', 'Ю').replace('Йо','Ё').replace('Йа','Я')
            #if 'ь' in sent:
                #print(key, sent.replace('\xa0', '').replace('ъ', 'ө').replace('Ъ', 'Ө').replace('\\', 'ү').replace('ё','ң').replace('/', 'Ү').replace('йа', 'я').replace('йу','ю').replace('йо','ё').replace('Марям','Марьям').replace('Йахя','Йахья').replace('Банямин','Баньямин').replace('Аюп','Айюп').replace('Аюб','Айюп').replace('Иляс', 'Ильяс').replace('Машар-ьул-Харамда','Машьар-ул-Харамда').replace('ьүберишкен', 'беришкен')) #.replace('Йу', 'Ю').replace('Йо','Ё').replace('Йа','Я')
            if name == 'fatihah' and texp== 'text':
                content['8'] = 'Өзүң бизди туура жолго баштагын,'
            if name == 'fatihah' and texp== 'explanation':
                content['3'] = '“Алла” – Кудайдын арабча аталышы. Бирок, арабчада “Аллах” деп сөздүн аягында кыргыз элинин түштүктүк диалектиндеги “h” тыбышы менен айтылат. Демек, “Алла” деген сөздүн аягында “h” – тамактын түпкүрүнөн чыгуучу жумшак “х” тыбышын колдонууга милдеттүүбүз.'
            if name == 'fatihah' and texp== 'explanation':
                content['7'] = '“Алланын каарына калгандар – Иудейлер, адашкандар христиандар” – деп да айтылат(Тафсир Ал-Байзавий).'
            if name == 'saba' and texp == 'explanation':
                content['1'] = 'Саба – бүгүнкү күндөгү Йемендин борбор шаарына тиешелүү анын байыркы аталышы.'
        for key, sent in content.items():
            if '-' in sent: #name == 'anam':
                if key == '1' :
                    print(key, sent)
# Out:
# 1 Фатиха - бетачар.
# 1 Бакара-Уй
# 1 Исраа -Түнкү жүрүш
# 1 Кахф - Үңкүр
# 1 («То» ,«ха» - араб алфавитиндеги тамгалардан. Бул жерде алар кандай мааниге ээ экени бир гана Алла Тааланын өзүнө гана малым
# 1 Анбия - Пайгамбарлар.
# 1 Хаж - Хаж, ажылык
# 1 Му-минуун - момундар, Аллага чын ыкластан берилген пенделер, анык мусулмандар.
# 1 24-сүрө, «Нур»
# 1 Фуркан - жамандык менен жакшылыкты ажыратуучу.
# 1 26-сүрө, «Шуара»
# 1 Шуара -Акындар
# 1 Намл - кумурска.
# 1 28-сүрө «К асас »
# 1 Касас -Аңгемелер, болгон окуялар
# 1 Анкабут - жөргөмүш.
# 1 30-сүрө «Рум »
# 1 «Рум» - Чыгыш Рим империясы, Византия аталган мамлекеттин араб тилинде аталышы
# 1 Лукман - улукман, даанышман.
# 1 Сажда - маңдайын жерге тийгизип сежде кылуу.
# 1 33- сүрө «Ахзаб[1]»
# 1 Ахзаб - «топтор». Мусулмандаргакаршы согушууга мушриктерден жана иудейлерден куралган.
# 1 35- сүрө «Фаатир »
# 1 Фаатир - Жаратуучу
# 1 37-сүрө «Сааффат[1]»
# 1 Сааффат - Сапка тизилүүчүлөр
# 1 39-сүрө «Зумар »
# 1 Зумар - тайпалар
# ...

# %%
listic = []
for index, row in df.iterrows():
    listic.append(
        {
            'id': index,
            'name': (row['explanation']['1'].split('-')[0] if '-' in row['explanation']['1'] else row['explanation']['1']).replace('.','').strip(),
            'meaning': (''.join(row['explanation']['1'].split('-')[1:]) if '-' in row['explanation']['1'] else row['explanation']['1']).strip()
        }
    )

# %%
listic
# Out:
# [{'id': 'fatihah', 'name': 'Фатиха', 'meaning': 'бетачар.'},
#  {'id': 'baqarah', 'name': 'Бакара', 'meaning': 'Уй'},
#  {'id': 'al_e_imran',
#   'name': 'Имрандын үй бүлөсү',
#   'meaning': 'Имрандын үй бүлөсү'},
#  {'id': 'nisa', 'name': 'Аялдар', 'meaning': 'Аялдар'},
#  {'id': 'maidah', 'name': 'Дасторкон', 'meaning': 'Дасторкон'},
#  {'id': 'anam', 'name': 'Үй жаныбарлары', 'meaning': 'Үй жаныбарлары'},
#  {'id': 'araf', 'name': 'Дубал', 'meaning': 'Дубал'},
#  {'id': 'anfal', 'name': 'Олжолор', 'meaning': 'Олжолор'},
#  {'id': 'tawbah', 'name': 'Тообо', 'meaning': 'Тообо'},
#  {'id': 'yunus',
#   'name': 'Мааниси бир Аллага маалым',
#   'meaning': 'Мааниси бир Аллага маалым.'},
#  {'id': 'hud',
#   'name': 'Мааниси бир Аллага маалым',
#   'meaning': 'Мааниси бир Аллага маалым'},
#  {'id': 'yusuf',
#   'name': 'Мааниси бир гана Аллага маалым',
#   'meaning': 'Мааниси бир гана Аллага маалым'},
#  {'id': 'rad', 'name': 'Күн күркүрөө', 'meaning': 'Күн күркүрөө'},
# ...

# %%
for row in listic:
    for key, value in row.items():
        if key == 'name':
            if value == 'Мааниси бир Аллага маалым' or value == 'Мааниси бир гана Аллага маалым' or value == 'Маанилери бир Аллага маалым' or value == 'Мааниси бир Аллага гана маалым':
                if row['id'] == 'yunus':
                    row['name'] = 'Йунус'
                if row['id'] == 'hud':
                    row['name'] = 'Хууд'
                if row['id'] == 'yusuf':
                    row['name'] = 'Йусуф'
                if row['id'] == 'ibrahim':
                    row['name'] = 'Ибрахим'
                if row['id'] == 'maryam':
                    row['name'] = 'Марьям'
                if row['id'] == 'yasin':
                    row['name'] = 'Йа Син'
                if row['id'] == 'sad':
                    row['name'] = 'Сод'
                if row['id'] == 'qaf':
                    row['name'] = 'Каф'
            if row['id'] == 'fatihah':
                row['name'] = 'аль-Фатиха'
            if row['id'] == 'baqarah':
                row['name'] = 'аль-Бакара'
            if row['id'] == 'al_e_imran':
                row['name'] = 'Аали ‘Имран'
            if row['id'] == 'nisa':
                row['name'] = 'ан-Ниса’'
            if row['id'] == 'maidah':
                row['name'] = 'аль-Маа’ида'
            if row['id'] == 'anam':
                row['name'] = 'аль-Ан‘ам'
            if row['id'] == 'araf':
                row['name'] = 'аль-А‘раф'
            if row['id'] == 'anfal':
                row['name'] = 'аль-Анфал'
            if row['id'] == 'tawbah':
                row['name'] = 'ат-Тауба'
            if row['id'] == 'yunus':
                row['name'] = 'Йунус'
            if row['id'] == 'hud':
                row['name'] = 'Хууд'
            if row['id'] == 'yusuf':
                row['name'] = 'Йусуф'
            if row['id'] == 'rad':
                row['name'] = 'Ар-Ра‘д'
            if row['id'] == 'ibrahim':
                row['name'] = 'Ибрахим'
            if row['id'] == 'hijr':
                row['name'] = 'Ал-Хижр'
            if row['id'] == 'nahl':
                row['name'] = 'Ан-Нахль'
            if row['id'] == 'isra':
                row['name'] = 'аль-Исра’'
            if row['id'] == 'kahf':
                row['name'] = 'аль-Кахф'
            if row['id'] == 'maryam':
                row['name'] = 'Марьям'
            if row['id'] == 'taha':
                row['name'] = 'То Ха'
            if row['id'] == 'anbiya':
                row['name'] = 'аль-Анбия’'
            if row['id'] == 'hajj':
                row['name'] = 'аль-Хажж'
            if row['id'] == 'muminoon':
                row['name'] = 'аль-Му’минун'
            if row['id'] == 'nur':
                row['name'] = 'ан-Нур'
            if row['id'] == 'furqan':
                row['name'] = 'аль-Фуркан'
            if row['id'] == 'shuara':
                row['name'] = 'аш-Шу‘ара’'
            if row['id'] == 'naml':
                row['name'] = 'ан-Намль'
            if row['id'] == 'qasas':
                row['name'] = 'аль-Касас'
            if row['id'] == 'ankabut':
                row['name'] = 'аль-‘Анкабут'
            if row['id'] == 'rum':
                row['name'] = 'ар-Рум'
            if row['id'] == 'luqman':
                row['name'] = 'Лукман'
            if row['id'] == 'sajdah':
                row['name'] = 'ас-Сажда'
            if row['id'] == 'ahzab':
                row['name'] = 'аль-Ахзаб'
            if row['id'] == 'saba':
                row['name'] = 'Саба'
            if row['id'] == 'fatir':
                row['name'] = 'Фаатыр'
            if row['id'] == 'yasin':
                row['name'] = 'Йа Син'
            if row['id'] == 'saffat':
                row['name'] = 'ас-Сааффат'
            if row['id'] == 'sad':
                row['name'] = 'Сод'
            if row['id'] == 'zumar':
                row['name'] = 'аз-Зумар'
            if row['id'] == 'ghafir':
                row['name'] = 'Гаафир'
            if row['id'] == 'fussilat':
                row['name'] = 'Фуссялят'
            if row['id'] == 'shura':
                row['name'] = 'аш-Шура'
            if row['id'] == 'zukhruf':
                row['name'] = 'аз-Зухруф'
            if row['id'] == 'dukhan':
                row['name'] = 'ад-Духан'
            if row['id'] == 'jathiyah':
                row['name'] = 'аль-Жаасия'
            if row['id'] == 'ahqaf':
                row['name'] = 'аль-Ахкаф'
            if row['id'] == 'muhammad':
                row['name'] = 'Мухаммед'
            if row['id'] == 'fath':
                row['name'] = 'аль-Фатх'
            if row['id'] == 'hujurat':
                row['name'] = 'аль-Хужураат'
            if row['id'] == 'qaf':
                row['name'] = 'Каф'
            if row['id'] == 'dhariyat':
                row['name'] = 'аз-Заарият'
            if row['id'] == 'tur':
                row['name'] = 'ат-Тур'
            if row['id'] == 'najm':
                row['name'] = 'ан-Нажм'
            if row['id'] == 'qamar':
                row['name'] = 'аль-Камар'
            if row['id'] == 'rahman':
                row['name'] = 'Ар-Рахман'
            if row['id'] == 'waqiah':
                row['name'] = 'аль-Вакы‘а'
            if row['id'] == 'hadid':
                row['name'] = 'аль-Хадид'
            if row['id'] == 'mujadilah':
                row['name'] = 'аль-Мужадила'
            if row['id'] == 'hashr':
                row['name'] = 'аль-Хашр'
            if row['id'] == 'mumtahanah':
                row['name'] = 'аль-Мумтахана'
            if row['id'] == 'saff':
                row['name'] = 'ас-Софф'
            if row['id'] == 'jumuah':
                row['name'] = 'аль-Жуму‘а'
            if row['id'] == 'munafiqun':
                row['name'] = 'аль-Мунафикун'
            if row['id'] == 'taghabun':
                row['name'] = 'ат-Тагаабун'
            if row['id'] == 'talaq':
                row['name'] = 'ат-Талак'
            if row['id'] == 'tahrim':
                row['name'] = 'ат-Тахрим'
            if row['id'] == 'mulk':
                row['name'] = 'аль-Мульк'
            if row['id'] == 'qalam':
                row['name'] = 'аль-Калам'
            if row['id'] == 'haqqah':
                row['name'] = 'аль-Хаакка'
            if row['id'] == 'maarij':
                row['name'] = 'аль-Ма‘ариж'
            if row['id'] == 'nuh':
                row['name'] = 'Нух'
            if row['id'] == 'jinn':
                row['name'] = 'аль-Жинн'
            if row['id'] == 'muzzammil':
                row['name'] = 'аль-Муззаммил'
            if row['id'] == 'muddathir':
                row['name'] = 'аль-Муддассир'
            if row['id'] == 'qiyamah':
                row['name'] = 'аль-Кыяма'
            if row['id'] == 'insan':
                row['name'] = 'аль-Инсан'
            if row['id'] == 'mursalat':
                row['name'] = 'аль-Мурсалят'
            if row['id'] == 'naba':
                row['name'] = 'ан-Наба’'
            if row['id'] == 'naziat':
                row['name'] = 'ан-Нази‘ат'
            if row['id'] == 'abasa':
                row['name'] = '‘Абаса'
            if row['id'] == 'takwir':
                row['name'] = 'ат-Таквир'
            if row['id'] == 'infitar':
                row['name'] = 'аль-Инфитар'
            if row['id'] == 'mutaffifin':
                row['name'] = 'аль-Мутоффифин'
            if row['id'] == 'inshiqaq':
                row['name'] = 'аль-Иншикак'
            if row['id'] == 'buruj':
                row['name'] = 'аль-Буруж'
            if row['id'] == 'tariq':
                row['name'] = 'ат-Торик'
            if row['id'] == 'ala':
                row['name'] = 'аль-А‘ля'
            if row['id'] == 'ghashiyah':
                row['name'] = 'аль-Гаашия'
            if row['id'] == 'fajr':
                row['name'] = 'аль-Фажр'
            if row['id'] == 'balad':
                row['name'] = 'аль-Балад'
            if row['id'] == 'shams':
                row['name'] = 'аш-Шамс'
            if row['id'] == 'lail':
                row['name'] = 'аль-Ляйл'
            if row['id'] == 'duha':
                row['name'] = 'ад-Духа'
            if row['id'] == 'sharh':
                row['name'] = 'аль-Инширах'
            if row['id'] == 'tin':
                row['name'] = 'ат-Тин'
            if row['id'] == 'alaq':
                row['name'] = 'аль-‘Алак'
            if row['id'] == 'qadr':
                row['name'] = 'аль-Кадр'
            if row['id'] == 'bayyinah':
                row['name'] = 'аль-Баййина'
            if row['id'] == 'zalzalah':
                row['name'] = 'аз-Залзала'
            if row['id'] == 'adiyat':
                row['name'] = 'аль-‘Адият'
            if row['id'] == 'qariah':
                row['name'] = 'аль-Коори‘а'
            if row['id'] == 'takathur':
                row['name'] = 'ат-Такаасур'
            if row['id'] == 'asr':
                row['name'] = 'аль-‘Аср'
            if row['id'] == 'humazah':
                row['name'] = 'аль-Хумаза'
            if row['id'] == 'fil':
                row['name'] = 'аль-Фил'
            if row['id'] == 'quraish':
                row['name'] = 'Курайш'
            if row['id'] == 'maun':
                row['name'] = 'аль-Маа‘уун'
            if row['id'] == 'kawthar':
                row['name'] = 'аль-Каусар'
            if row['id'] == 'kafirun':
                row['name'] = 'аль-Каафирун'
            if row['id'] == 'nasr':
                row['name'] = 'ан-Наср'
            if row['id'] == 'masad':
                row['name'] = 'аль-Масад'
            if row['id'] == 'ikhlas':
                row['name'] = 'аль-Ихлас'
            if row['id'] == 'falaq':
                row['name'] = 'аль-Фалак'
            if row['id'] == 'nas':
                row['name'] = 'ан-Наас'
            # ‘ - ain, ’ - hamza
            #row['meaning'] = ''.join(row['meaning'].split('-')[1:])
            print(row['id'], row['name']) #, row['meaning']
# Out:
# fatihah аль-Фатиха
# baqarah аль-Бакара
# al_e_imran Аали ‘Имран
# nisa ан-Ниса’
# maidah аль-Маа’ида
# anam аль-Ан‘ам
# araf аль-А‘раф
# anfal аль-Анфал
# tawbah ат-Тауба
# yunus Йунус
# hud Хууд
# yusuf Йусуф
# rad Ар-Ра‘д
# ibrahim Ибрахим
# hijr Ал-Хижр
# nahl Ан-Нахль
# isra аль-Исра’
# kahf аль-Кахф
# maryam Марьям
# taha То Ха
# anbiya аль-Анбия’
# hajj аль-Хажж
# muminoon аль-Му’минун
# nur ан-Нур
# furqan аль-Фуркан
# shuara аш-Шу‘ара’
# naml ан-Намль
# qasas аль-Касас
# ankabut аль-‘Анкабут
# rum ар-Рум
# luqman Лукман
# sajdah ас-Сажда
# ahzab аль-Ахзаб
# saba Саба
# fatir Фаатыр
# yasin Йа Син
# saffat ас-Сааффат
# sad Сод
# zumar аз-Зумар
# ghafir Гаафир
# fussilat Фуссялят
# shura аш-Шура
# zukhruf аз-Зухруф
# dukhan ад-Духан
# jathiyah аль-Жаасия
# ahqaf аль-Ахкаф
# muhammad Мухаммед
# fath аль-Фатх
# hujurat аль-Хужураат
# qaf Каф
# dhariyat аз-Заарият
# tur ат-Тур
# najm ан-Нажм
# qamar аль-Камар
# rahman Ар-Рахман
# waqiah аль-Вакы‘а
# hadid аль-Хадид
# ...

# %%
for row in listic:
    if row['id'] == 'maryam':
        row['meaning'] = 'Марьям - Иса пайгамбардын (а.с.) апасы'
    if row['meaning'][-1] == '.':
        row['meaning'] = row['meaning'][:-1]
    if row['meaning'][0].islower():
        row['meaning'] = row['meaning'][0].upper() + row['meaning'][1:]
    if row['id'] in ['taha', 'yasin', 'sad', 'qaf']:
        row['meaning'] = row['name']
    if row['id'] == 'adiyat':
        row['meaning'] = 'Дүбүрттүү күлүк'
    if row['id'] == 'muminoon':
        row['meaning'] = 'Момундар, Аллага чын ыкластан берилген пенделер, анык мусулмандар'
    if row['id'] == 'nur':
        row['meaning'] = 'Нур'
    if row['id'] == 'ahzab':
        row['meaning'] = 'Топтор. Мусулмандарга каршы согушууга мушриктерден жана иудейлерден куралган топтор'
    if row['id'] == 'muhammad':
        row['meaning'] = 'Мухаммед пайгамбар (а.с.)'
    if row['id'] == 'hujurat':
        row['meaning'] = 'Бөлмөлөр'
    if row['id'] == 'rahman':
        row['meaning'] = 'Аллахтын улуу ысым-сыпаттарынын бири'
    if row['id'] == 'jumuah':
        row['meaning'] = 'Жума'
    if row['id'] == 'taghabun':
        row['meaning'] = 'Бири-бирин алдоо'
    if row['id'] == 'nuh':
        row['meaning'] = 'Нух пайгамбар (а.с.)'
    if row['id'] == 'yunus':
        row['meaning'] = 'Йунус пайгамбар (а.с.)'
    if row['id'] == 'hud':
        row['meaning'] = 'Хууд пайгамбар (а.с.)'
    if row['id'] == 'yusuf':
        row['meaning'] = 'Йусуп пайгамбар (а.с.)'
    if row['id'] == 'ibrahim':
        row['meaning'] = 'Ибрахим пайгамбар (а.с.)'
    if row['id'] == 'qiyamah':
        row['meaning'] = 'Кыямат'
    if row['id'] == 'qadr':
        row['meaning'] = 'Кадыр'
    if row['id'] == 'bayyinah':
        row['meaning'] = 'Ачык-айкын кабар'
    if row['id'] == 'zalzalah':
        row['meaning'] = 'Жер титирөө'
    if row['id'] == 'takathur':
        row['meaning'] = 'Сыймыктануу, мактануу'
    if row['id'] == 'asr':
        row['meaning'] = 'Кылым'
    if row['id'] == 'kawthar':
        row['meaning'] = 'Каусар'
    if row['id'] == 'insan':
        row['meaning'] = 'Инсан'
    if row['id'] == 'muddathir':
        row['meaning'] = 'Чүмкөнүп алган (Адам)'
    if row['id'] == 'rum':
        row['meaning'] = 'Чыгыш Рим империясы'
    if row['id'] == 'jinn':
        row['meaning'] = 'Жин'
    print(row['id'], "|", row['name'], "|", row['meaning'])
# Out:
# fatihah | аль-Фатиха | Бетачар
# baqarah | аль-Бакара | Уй
# al_e_imran | Аали ‘Имран | Имрандын үй бүлөсү
# nisa | ан-Ниса’ | Аялдар
# maidah | аль-Маа’ида | Дасторкон
# anam | аль-Ан‘ам | Үй жаныбарлары
# araf | аль-А‘раф | Дубал
# anfal | аль-Анфал | Олжолор
# tawbah | ат-Тауба | Тообо
# yunus | Йунус | Йунус пайгамбар (а.с.)
# hud | Хууд | Хууд пайгамбар (а.с.)
# yusuf | Йусуф | Йусуп пайгамбар (а.с.)
# rad | Ар-Ра‘д | Күн күркүрөө
# ibrahim | Ибрахим | Ибрахим пайгамбар (а.с.)
# hijr | Ал-Хижр | Өрөөн
# nahl | Ан-Нахль | Бал аары
# isra | аль-Исра’ | Түнкү жүрүш
# kahf | аль-Кахф | Үңкүр
# maryam | Марьям | Марьям - Иса пайгамбардын (а.с.) апасы
# taha | То Ха | То Ха
# anbiya | аль-Анбия’ | Пайгамбарлар
# hajj | аль-Хажж | Хаж, ажылык
# muminoon | аль-Му’минун | Момундар, Аллага чын ыкластан берилген пенделер, анык мусулмандар
# nur | ан-Нур | Нур
# furqan | аль-Фуркан | Жамандык менен жакшылыкты ажыратуучу
# shuara | аш-Шу‘ара’ | Акындар
# naml | ан-Намль | Кумурска
# ...

# %%
# for i in range(len(listic)):
#     listic[i]['translation'] = listic[i]['name'].split('-')[0].strip().split('–')[0].strip().replace('/', 'ү').capitalize()
#     print(listic[i])
listic
# Out:
# [{'id': 'fatihah', 'name': 'аль-Фатиха', 'meaning': 'Бетачар'},
#  {'id': 'baqarah', 'name': 'аль-Бакара', 'meaning': 'Уй'},
#  {'id': 'al_e_imran', 'name': 'Аали ‘Имран', 'meaning': 'Имрандын үй бүлөсү'},
#  {'id': 'nisa', 'name': 'ан-Ниса’', 'meaning': 'Аялдар'},
#  {'id': 'maidah', 'name': 'аль-Маа’ида', 'meaning': 'Дасторкон'},
#  {'id': 'anam', 'name': 'аль-Ан‘ам', 'meaning': 'Үй жаныбарлары'},
#  {'id': 'araf', 'name': 'аль-А‘раф', 'meaning': 'Дубал'},
#  {'id': 'anfal', 'name': 'аль-Анфал', 'meaning': 'Олжолор'},
#  {'id': 'tawbah', 'name': 'ат-Тауба', 'meaning': 'Тообо'},
#  {'id': 'yunus', 'name': 'Йунус', 'meaning': 'Йунус пайгамбар (а.с.)'},
#  {'id': 'hud', 'name': 'Хууд', 'meaning': 'Хууд пайгамбар (а.с.)'},
#  {'id': 'yusuf', 'name': 'Йусуф', 'meaning': 'Йусуп пайгамбар (а.с.)'},
#  {'id': 'rad', 'name': 'Ар-Ра‘д', 'meaning': 'Күн күркүрөө'},
#  {'id': 'ibrahim', 'name': 'Ибрахим', 'meaning': 'Ибрахим пайгамбар (а.с.)'},
# ...

# %%
listic
# Out:
# [{'id': 'fatihah', 'name': 'аль-Фатиха', 'meaning': 'Бетачар'},
#  {'id': 'baqarah', 'name': 'аль-Бакара', 'meaning': 'Уй'},
#  {'id': 'al_e_imran', 'name': 'Аали ‘Имран', 'meaning': 'Имрандын үй бүлөсү'},
#  {'id': 'nisa', 'name': 'ан-Ниса’', 'meaning': 'Аялдар'},
#  {'id': 'maidah', 'name': 'аль-Маа’ида', 'meaning': 'Дасторкон'},
#  {'id': 'anam', 'name': 'аль-Ан‘ам', 'meaning': 'Үй жаныбарлары'},
#  {'id': 'araf', 'name': 'аль-А‘раф', 'meaning': 'Дубал'},
#  {'id': 'anfal', 'name': 'аль-Анфал', 'meaning': 'Олжолор'},
#  {'id': 'tawbah', 'name': 'ат-Тауба', 'meaning': 'Тообо'},
#  {'id': 'yunus', 'name': 'Йунус', 'meaning': 'Йунус пайгамбар (а.с.)'},
#  {'id': 'hud', 'name': 'Хууд', 'meaning': 'Хууд пайгамбар (а.с.)'},
#  {'id': 'yusuf', 'name': 'Йусуф', 'meaning': 'Йусуп пайгамбар (а.с.)'},
#  {'id': 'rad', 'name': 'Ар-Ра‘д', 'meaning': 'Күн күркүрөө'},
#  {'id': 'ibrahim', 'name': 'Ибрахим', 'meaning': 'Ибрахим пайгамбар (а.с.)'},
# ...

# %%
for i in listic:
    print(i['name'])
# Out:
# аль-Фатиха
# аль-Бакара
# Аали ‘Имран
# ан-Ниса’
# аль-Маа’ида
# аль-Ан‘ам
# аль-А‘раф
# аль-Анфал
# ат-Тауба
# Йунус
# Хууд
# Йусуф
# Ар-Ра‘д
# Ибрахим
# Ал-Хижр
# Ан-Нахль
# аль-Исра’
# аль-Кахф
# Марьям
# То Ха
# аль-Анбия’
# аль-Хажж
# аль-Му’минун
# ан-Нур
# аль-Фуркан
# аш-Шу‘ара’
# ан-Намль
# аль-Касас
# аль-‘Анкабут
# ар-Рум
# Лукман
# ас-Сажда
# аль-Ахзаб
# Саба
# Фаатыр
# Йа Син
# ас-Сааффат
# Сод
# аз-Зумар
# Гаафир
# Фуссялят
# аш-Шура
# аз-Зухруф
# ад-Духан
# аль-Жаасия
# аль-Ахкаф
# Мухаммед
# аль-Фатх
# аль-Хужураат
# Каф
# аз-Заарият
# ат-Тур
# ан-Нажм
# аль-Камар
# Ар-Рахман
# аль-Вакы‘а
# аль-Хадид
# аль-Мужадила
# аль-Хашр
# аль-Мумтахана
# ас-Софф
# аль-Жуму‘а
# Мунафикуун
# ат-Тагаабун
# ат-Талак
# ат-Тахрим
# аль-Мульк
# аль-Калам
# аль-Хаакка
# аль-Ма‘ариж
# Нух
# аль-Жинн
# аль-Муззаммил
# аль-Муддассир
# аль-Кыяма
# аль-Инсан
# аль-Мурсалят
# ан-Наба’
# ан-Нази‘ат
# ‘Абаса
# ат-Таквир
# аль-Инфитар
# аль-Мутоффифин
# аль-Иншикак
# аль-Буруж
# ат-Торик
# ...

# %%
type(listic)
# Out:
# list

# %%
json_data = json.dumps(listic, indent=4, ensure_ascii=True)

# Write pretty-printed JSON data to a file with ASCII encoding
with open('surah_names_meanings.json', 'w', encoding='ascii') as json_file:
    json_file.write(json_data)
